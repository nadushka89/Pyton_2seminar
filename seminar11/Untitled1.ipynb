# %% [markdown]
# f(x) = -12x**4sin(cos(x)) - 18x**3+5x*2 + 10x - 30
#
# Определить корни
#
# Найти интервалы, на которых функция возрастает
#
# Найти интервалы, на которых функция убывает
#
# Построить график
#
# Вычислить вершину
#
# Определить промежутки, на котором f > 0
#
# Определить промежутки, на котором f < 0

# %%
import math
from sympy import *
import matplotlib.pyplot as plt
import numpy as np

# %%
a, b, c,d,e = -12, -18, 5 , 10, -30
x = Symbol('x')
f_x = -12*x**4*sin(cos(x))-18*x**3+5*x**2 + 10*x-30
f_x
# Out:
# -12*x**4*sin(cos(x)) - 18*x**3 + 5*x**2 + 10*x - 30

# %%
# def f_x(a, b, c,d,e, x):
#     return  a*x**4*sin(cos(x))- b*x**3+c*x*2 + d*x - e

# %%
# a, b, c,d, e = -12, -18, 5 , 10, -30
# x = np.arange(-100, 100, 0.01)

# %%
pr=diff(f_x) # находим производную
print(pr)
# Out:
# 12*x**4*sin(x)*cos(cos(x)) - 48*x**3*sin(cos(x)) - 54*x**2 + 10*x + 10

# %%
p=plot(f_x, pr, (x,-100,100), legend= True, xlabel= 'X', ylabel= 'Y') # рисуем

# %%
#исходя из графика, видно, что корней бесконечное множество.

# %%
p1=plot(f_x,(x,-1.5,1.5,0.1)) # рисуем

# %% [markdown]
# Вычисление корней:

# %%
x = Symbol('x')
f_x= -12*x**4
solve(f_x)
# Out:
# [0]

# %%
x = Symbol('x')
f_x=sin(cos(x))
solve(f_x)
# Out:
# [pi/2, 3*pi/2, 2*pi - acos(pi), acos(pi)]

# %%
x = Symbol('x')
f_x=18*x**3+5*x*2 + 10*x - 30
solve(f_x)
# Out:
# [(-1/2 - sqrt(3)*I/2)*(5/6 + 5*sqrt(7041)/486)**(1/3) - 10/(27*(-1/2 - sqrt(3)*I/2)*(5/6 + 5*sqrt(7041)/486)**(1/3)),
#  -10/(27*(-1/2 + sqrt(3)*I/2)*(5/6 + 5*sqrt(7041)/486)**(1/3)) + (-1/2 + sqrt(3)*I/2)*(5/6 + 5*sqrt(7041)/486)**(1/3),
#  -10/(27*(5/6 + 5*sqrt(7041)/486)**(1/3)) + (5/6 + 5*sqrt(7041)/486)**(1/3)]

# %% [markdown]
# Функция −12𝑥4−18𝑥3+5𝑥2+10𝑥−30

# %%
x = Symbol('x')
f_x = -12*x**4-18*x**3+5*x**2+10*x-30
f_x
# Out:
# -12*x**4 - 18*x**3 + 5*x**2 + 10*x - 30

# %%
p = plot(f_x, (x, -100, 100))

# %%
print(solve(f_x))
# Out:
# [-3/8 - sqrt(121/144 + 4885/(2592*(208045/373248 + 5*sqrt(9048041)*I/20736)**(1/3)) + 2*(208045/373248 + 5*sqrt(9048041)*I/20736)**(1/3))/2 - sqrt(121/72 - 2*(208045/373248 + 5*sqrt(9048041)*I/20736)**(1/3) - 19/(96*sqrt(121/144 + 4885/(2592*(208045/373248 + 5*sqrt(9048041)*I/20736)**(1/3)) + 2*(208045/373248 + 5*sqrt(9048041)*I/20736)**(1/3))) - 4885/(2592*(208045/373248 + 5*sqrt(9048041)*I/20736)**(1/3)))/2, -3/8 + sqrt(121/144 + 4885/(2592*(208045/373248 + 5*sqrt(9048041)*I/20736)**(1/3)) + 2*(208045/373248 + 5*sqrt(9048041)*I/20736)**(1/3))/2 - sqrt(121/72 - 2*(208045/373248 + 5*sqrt(9048041)*I/20736)**(1/3) + 19/(96*sqrt(121/144 + 4885/(2592*(208045/373248 + 5*sqrt(9048041)*I/20736)**(1/3)) + 2*(208045/373248 + 5*sqrt(9048041)*I/20736)**(1/3))) - 4885/(2592*(208045/373248 + 5*sqrt(9048041)*I/20736)**(1/3)))/2, -3/8 + sqrt(121/72 - 2*(208045/373248 + 5*sqrt(9048041)*I/20736)**(1/3) - 19/(96*sqrt(121/144 + 4885/(2592*(208045/373248 + 5*sqrt(9048041)*I/20736)**(1/3)) + 2*(208045/37
# ...

# %%
pr = diff(f_x)
print(pr)
# Out:
# -48*x**3 - 54*x**2 + 10*x + 10

# %%
apex = solve(diff(f_x))[0] # вершина
print(apex)
# Out:
# -3/8 + (-1/2 - sqrt(3)*I/2)*(19/1536 + sqrt(108895)*I/3456)**(1/3) + 121/(576*(-1/2 - sqrt(3)*I/2)*(19/1536 + sqrt(108895)*I/3456)**(1/3))

# %%
solve(diff(f_x) > 0) # интервалы, на которых функция возрастает
# Out:
# ((-oo < x) & (x < CRootOf(24*x**3 + 27*x**2 - 5*x - 5, 0))) | ((x < CRootOf(24*x**3 + 27*x**2 - 5*x - 5, 2)) & (CRootOf(24*x**3 + 27*x**2 - 5*x - 5, 1) < x))

# %%
solve(diff(f_x) < 0) # интервалы, на которых функция убывает
# Out:
# ((x < oo) & (CRootOf(24*x**3 + 27*x**2 - 5*x - 5, 2) < x)) | ((x < CRootOf(24*x**3 + 27*x**2 - 5*x - 5, 1)) & (CRootOf(24*x**3 + 27*x**2 - 5*x - 5, 0) < x))

# %%
solve(f_x > 0)
# Out:
# False

# %%
solve(f_x < 0)
# Out:
# (-oo < x) & (x < oo)
